# %% [markdown]
# <a href="https://colab.research.google.com/github/ghantasalasoubhagya00-source/GENERATIVE-AI-PROJECTS/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

print("TIMETABLE GENERATOR\n")

#user inputs
subjects_input = input("enter subjets(coma separater):")
days_input = input("enter days (coma separated):")
periods_per_day = int(input("enter number of periods per day:"))

#process inputs
subjects = [s.strip() for s in subjects_input.split(",") if s.strip()]
days = [d.strip() for d in days_input.split(",") if d.strip()]

# validation
if len(subjects) == 0 or len(days) == 0 or periods_per_day <= 0:
    print("Invalid input. please try again.")
else:
    timetable = {}

    for day in days:
        timetable[day] = random.choices(subjects, k=periods_per_day)

    # create dataframe
    df = pd.DataFrame(timetable)
    df.index = [f"period {i+1}"for i in range(periods_per_day)]

    print("\nTimetable Generated successfully\n")
    display(df)

    #save timetable
    df.to_csv("timetable.csv")
    print("\nTimetable saved as timetable.csv")
# Out:
# TIMETABLE GENERATOR
#
# enter subjets(coma separater):maths,
# enter days (coma separated):monday,tuesday,wednesday
# enter number of periods per day:5
#
# Timetable Generated successfully
#          monday tuesday wednesday
# period 1  maths   maths     maths
# period 2  maths   maths     maths
# period 3  maths   maths     maths
# period 4  maths   maths     maths
# period 5  maths   maths     maths
# Timetable saved as timetable.csv
